# %%
import requests
from bs4 import BeautifulSoup

# %%
result=requests.get("https://www.coa.nl/mycoa/en")
print(result.status_code)
# Out:
# 200

# %%
v_number=input("voer v nummer in")

result=requests.get("https://www.coa.nl/mycoa/nl/content/post?field_post_v_nummer_value=2864620493&submit_me=1")
print(result.status_code)
# Out:
# voer v nummer in2
# 200

# %%
src=result.content
soup=BeautifulSoup(src,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
#   "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
#
# <html dir="ltr" lang="nl" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta charset="utf-8"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, target-densityDpi=device-dpi" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="Drupal 7 (http://drupal.org)" name="Generator">
# <link href="/nl/content/post" rel="canonical"/>
# <link href="/nl/node/11586" rel="shortlink"/>
# ...

# %%
hebt=soup.find("img",{"src":"https://www.coa.nl/mycoa/sites/default/files/styles/thumbnail/public/post_rood.png?itok=FtFRZJEE"})
if hebt==None:
    print("Geen Post")
else:
    print("Je Hebt Post")
# Out:
# Geen Post

# %%
geen=soup.find("img",{"src":"https://www.mycoa.nl/sites/default/files/styles/thumbnail/public/post_rood.png?itok=k-j5iVzC"})
if geen==None:
    print("Je Hebt Post")
else:
    print("Geen Post")
# Out:
# Geen Post
